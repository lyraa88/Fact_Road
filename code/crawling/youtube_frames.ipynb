# %%
pip install yt-dlp
# Out:
# Collecting yt-dlp
#   Downloading yt_dlp-2024.11.4-py3-none-any.whl.metadata (172 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.1/172.1 kB 3.8 MB/s eta 0:00:00
# Downloading yt_dlp-2024.11.4-py3-none-any.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 42.3 MB/s eta 0:00:00
# Installing collected packages: yt-dlp
# Successfully installed yt-dlp-2024.11.4

# %%
import cv2
import os
import yt_dlp
import pandas as pd

def capture_frames_from_youtube(video_id, output_dir="frames", interval_seconds=4, speed_factor=20):
    try:
        # 각 비디오 ID에 대한 출력 디렉토리 생성
        video_output_dir = os.path.join(output_dir, video_id)
        os.makedirs(video_output_dir, exist_ok=True)

        # yt_dlp를 사용하여 비디오 URL을 직접 가져오기
        video_url = f"https://www.youtube.com/watch?v={video_id}"

        ydl_opts = {'format': 'best'}
        with yt_dlp.YoutubeDL(ydl_opts) as ydl:
            info_dict = ydl.extract_info(video_url, download=False)
            video_stream_url = info_dict.get("url")
            duration = info_dict.get("duration")  # 비디오 길이(초)

        # OpenCV로 비디오 스트림 열기
        cap = cv2.VideoCapture(video_stream_url)

        # 효과적인 길이 및 캡처할 프레임 수 계산
        effective_duration = duration / speed_factor  # 조정된 비디오 길이
        total_frames_to_capture = int(effective_duration / interval_seconds)  # 조정된 길이에 따라 캡처할 총 프레임 수

        frame_count = 0
        capture_count = 0
        captured_frames = []  # 캡처된 프레임을 저장할 리스트

        while cap.isOpened() and capture_count < total_frames_to_capture:
            ret, frame = cap.read()

            if not ret:
                break

            # 캡처할 시간인지 확인
            if frame_count % (int(cap.get(cv2.CAP_PROP_FPS)) * interval_seconds) == 0:
                frame_name = os.path.join(video_output_dir, f"frame_{capture_count}.jpg")
                cv2.imwrite(frame_name, frame)
                print(f"Captured {frame_name}")
                captured_frames.append(frame)  # 캡처된 프레임을 리스트에 추가
                capture_count += 1

            frame_count += 1

        # 평균 프레임 수 계산
        avg_frame_count = len(captured_frames)
        print(f"Video {video_id} captured {avg_frame_count} frames.")

        # 리소스 해제
        cap.release()
        cv2.destroyAllWindows()

        return avg_frame_count  # 평균 프레임 수 반환

    except Exception as e:
        print(f"비디오 {video_id}에서 오류 발생: {e}")
        return 0  # 오류 발생 시 0 반환

# CSV에서 비디오 ID 로드
csv_file_path = "combined_video_ids.csv"  # CSV 파일 경로
d = pd.read_csv(csv_file_path)

# 비디오 ID 상위 5개에 대해 캡처 함수 실행 및 평균 프레임 수 계산
video_ids = d["videoId"]  # 모든 비디오 ID 선택
avg_frame_counts = []

for video_id in video_ids:
    avg_frames = capture_frames_from_youtube(video_id, output_dir="frames")
    avg_frame_counts.append(avg_frames)

# 평균 프레임 수를 CSV로 저장 (선택사항)
avg_frame_df = pd.DataFrame({
    "videoId": video_ids,
    "averageFrameCount": avg_frame_counts
})

avg_frame_df.to_csv("average_frame_counts.csv", index=False)
print("Average frame counts saved to 'average_frame_counts.csv'.")
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# Captured frames/De_P6JqLCBM/frame_394.jpg
# Captured frames/De_P6JqLCBM/frame_395.jpg
# Captured frames/De_P6JqLCBM/frame_396.jpg
# Captured frames/De_P6JqLCBM/frame_397.jpg
# Captured frames/De_P6JqLCBM/frame_398.jpg
# Captured frames/De_P6JqLCBM/frame_399.jpg
# Captured frames/De_P6JqLCBM/frame_400.jpg
# Captured frames/De_P6JqLCBM/frame_401.jpg
# Captured frames/De_P6JqLCBM/frame_402.jpg
# Captured frames/De_P6JqLCBM/frame_403.jpg
# Captured frames/De_P6JqLCBM/frame_404.jpg
# Captured frames/De_P6JqLCBM/frame_405.jpg
# Captured frames/De_P6JqLCBM/frame_406.jpg
# Captured frames/De_P6JqLCBM/frame_407.jpg
# Captured frames/De_P6JqLCBM/frame_408.jpg
# Captured frames/De_P6JqLCBM/frame_409.jpg
# Captured frames/De_P6JqLCBM/frame_410.jpg
# Captured frames/De_P6JqLCBM/frame_411.jpg
# Captured frames/De_P6JqLCBM/frame_412.jpg
# Captured frames/De_P6JqLCBM/frame_413.jpg
# Captured frames/De_P6JqLCBM/frame_414.jpg
# Captured frames/De_P6JqLCBM/frame_415.jpg
# Captured frames/De_P6JqLCBM/frame_416.jpg
# Captured frames/De_P6JqLCBM/frame_417.jpg
# Captured frames/De_P6JqLCBM/frame_418.jpg
# Captured frames/De_P6JqLCBM/frame_419.jpg
# Captured frames/De_P6JqLCBM/frame_420.jpg
# Captured frames/De_P6JqLCBM/frame_421.jpg
# Captured frames/De_P6JqLCBM/frame_422.jpg
# Captured frames/De_P6JqLCBM/frame_423.jpg
# Captured frames/De_P6JqLCBM/frame_424.jpg
# Captured frames/De_P6JqLCBM/frame_425.jpg
# Captured frames/De_P6JqLCBM/frame_426.jpg
# Captured frames/De_P6JqLCBM/frame_427.jpg
# Captured frames/De_P6JqLCBM/frame_428.jpg
# Captured frames/De_P6JqLCBM/frame_429.jpg
# Captured frames/De_P6JqLCBM/frame_430.jpg
# Captured frames/De_P6JqLCBM/frame_431.jpg
# Captured frames/De_P6JqLCBM/frame_432.jpg
# Captured frames/De_P6JqLCBM/frame_433.jpg
# Captured frames/De_P6JqLCBM/frame_434.jpg
# Captured frames/De_P6JqLCBM/frame_435.jpg
# Captured frames/De_P6JqLCBM/frame_436.jpg
# Captured frames/De_P6JqLCBM/frame_437.jpg
# Captured frames/De_P6JqLCBM/frame_438.jpg
# Captured frames/De_P6JqLCBM/frame_439.jpg
# Captured frames/De_P6JqLCBM/frame_440.jpg
# Captured frames/De_P6JqLCBM/frame_441.jpg
# Captured frames/De_P6JqLCBM/frame_442.jpg
# Captured frames/De_P6JqLCBM/frame_443.jpg
# Captured frames/De_P6JqLCBM/frame_444.jpg
# Captured frames/De_P6JqLCBM/frame_445.jpg
# Captured frames/De_P6JqLCBM/frame_446.jpg
# Captured frames/De_P6JqLCBM/frame_447.jpg
# Captured frames/De_P6JqLCBM/frame_448.jpg
# Captured frames/De_P6JqLCBM/frame_449.jpg
# Captured frames/De_P6JqLCBM/frame_450.jpg
# Captured frames/De_P6JqLCBM/frame_451.jpg
# Captured frames/De_P6JqLCBM/frame_452.jpg
# Captured frames/De_P6JqLCBM/frame_453.jpg
# Captured frames/De_P6JqLCBM/frame_454.jpg
# Captured frames/De_P6JqLCBM/frame_455.jpg
# Captured frames/De_P6JqLCBM/frame_456.jpg
# Captured frames/De_P6JqLCBM/frame_457.jpg
# Captured frames/De_P6JqLCBM/frame_458.jpg
# Captured frames/De_P6JqLCBM/frame_459.jpg
# Captured frames/De_P6JqLCBM/frame_460.jpg
# Captured frames/De_P6JqLCBM/frame_461.jpg
# Captured frames/De_P6JqLCBM/frame_462.jpg
# Captured frames/De_P6JqLCBM/frame_463.jpg
# Captured frames/De_P6JqLCBM/frame_464.jpg
# Captured frames/De_P6JqLCBM/frame_465.jpg
# Captured frames/De_P6JqLCBM/frame_466.jpg
# Captured frames/De_P6JqLCBM/frame_467.jpg
# Captured frames/De_P6JqLCBM/frame_468.jpg
# Captured frames/De_P6JqLCBM/frame_469.jpg
# Captured frames/De_P6JqLCBM/frame_470.jpg
# Captured frames/De_P6JqLCBM/frame_471.jpg
# Captured frames/De_P6JqLCBM/frame_472.jpg
# Captured frames/De_P6JqLCBM/frame_473.jpg
# Captured frames/De_P6JqLCBM/frame_474.jpg
# Captured frames/De_P6JqLCBM/frame_475.jpg
# Captured frames/De_P6JqLCBM/frame_476.jpg
# Captured frames/De_P6JqLCBM/frame_477.jpg
# Captured frames/De_P6JqLCBM/frame_478.jpg
# Captured frames/De_P6JqLCBM/frame_479.jpg
# Captured frames/De_P6JqLCBM/frame_480.jpg
# Captured frames/De_P6JqLCBM/frame_481.jpg
# Captured frames/De_P6JqLCBM/frame_482.jpg
# Captured frames/De_P6JqLCBM/frame_483.jpg
# Captured frames/De_P6JqLCBM/frame_484.jpg
# Captured frames/De_P6JqLCBM/frame_485.jpg
# Captured frames/De_P6JqLCBM/frame_486.jpg
# Captured frames/De_P6JqLCBM/frame_487.jpg
# Captured frames/De_P6JqLCBM/frame_488.jpg
# Captured frames/De_P6JqLCBM/frame_489.jpg
# Captured frames/De_P6JqLCBM/frame_490.jpg
# Captured frames/De_P6JqLCBM/frame_491.jpg
# Captured frames/De_P6JqLCBM/frame_492.jpg
# Captured frames/De_P6JqLCBM/frame_493.jpg
# Captured frames/De_P6JqLCBM/frame_494.jpg
# Captured frames/De_P6JqLCBM/frame_495.jpg
# Captured frames/De_P6JqLCBM/frame_496.jpg
# Captured frames/De_P6JqLCBM/frame_497.jpg
# Captured frames/De_P6JqLCBM/frame_498.jpg
# Captured frames/De_P6JqLCBM/frame_499.jpg
# Captured frames/De_P6JqLCBM/frame_500.jpg
# Captured frames/De_P6JqLCBM/frame_501.jpg
# Captured frames/De_P6JqLCBM/frame_502.jpg
# Captured frames/De_P6JqLCBM/frame_503.jpg
# Captured frames/De_P6JqLCBM/frame_504.jpg
# Captured frames/De_P6JqLCBM/frame_505.jpg
# Captured frames/De_P6JqLCBM/frame_506.jpg
# Captured frames/De_P6JqLCBM/frame_507.jpg
# Captured frames/De_P6JqLCBM/frame_508.jpg
# Captured frames/De_P6JqLCBM/frame_509.jpg
# Captured frames/De_P6JqLCBM/frame_510.jpg
# Captured frames/De_P6JqLCBM/frame_511.jpg
# Captured frames/De_P6JqLCBM/frame_512.jpg
# Captured frames/De_P6JqLCBM/frame_513.jpg
# Captured frames/De_P6JqLCBM/frame_514.jpg
# Captured frames/De_P6JqLCBM/frame_515.jpg
# Captured frames/De_P6JqLCBM/frame_516.jpg
# Captured frames/De_P6JqLCBM/frame_517.jpg
# Captured frames/De_P6JqLCBM/frame_518.jpg
# Captured frames/De_P6JqLCBM/frame_519.jpg
# Captured frames/De_P6JqLCBM/frame_520.jpg
# Captured frames/De_P6JqLCBM/frame_521.jpg
# Captured frames/De_P6JqLCBM/frame_522.jpg
# Captured frames/De_P6JqLCBM/frame_523.jpg
# Captured frames/De_P6JqLCBM/frame_524.jpg
# Captured frames/De_P6JqLCBM/frame_525.jpg
# Captured frames/De_P6JqLCBM/frame_526.jpg
# Captured frames/De_P6JqLCBM/frame_527.jpg
# Captured frames/De_P6JqLCBM/frame_528.jpg
# Captured frames/De_P6JqLCBM/frame_529.jpg
# Captured frames/De_P6JqLCBM/frame_530.jpg
# Captured frames/De_P6JqLCBM/frame_531.jpg
# Captured frames/De_P6JqLCBM/frame_532.jpg
# Captured frames/De_P6JqLCBM/frame_533.jpg
# Captured frames/De_P6JqLCBM/frame_534.jpg
# Captured frames/De_P6JqLCBM/frame_535.jpg
# Video De_P6JqLCBM captured 536 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=9xVTRXZ2EwE
# [youtube] 9xVTRXZ2EwE: Downloading webpage
# [youtube] 9xVTRXZ2EwE: Downloading ios player API JSON
# [youtube] 9xVTRXZ2EwE: Downloading mweb player API JSON
# [youtube] 9xVTRXZ2EwE: Downloading m3u8 information
# Captured frames/9xVTRXZ2EwE/frame_0.jpg
# Video 9xVTRXZ2EwE captured 1 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=8VZ_behKlBE
# [youtube] 8VZ_behKlBE: Downloading webpage
# [youtube] 8VZ_behKlBE: Downloading ios player API JSON
# [youtube] 8VZ_behKlBE: Downloading mweb player API JSON
# [youtube] 8VZ_behKlBE: Downloading m3u8 information
# Captured frames/8VZ_behKlBE/frame_0.jpg
# Captured frames/8VZ_behKlBE/frame_1.jpg
# Video 8VZ_behKlBE captured 2 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=VCbk25eZHwk
# [youtube] VCbk25eZHwk: Downloading webpage
# [youtube] VCbk25eZHwk: Downloading ios player API JSON
# [youtube] VCbk25eZHwk: Downloading mweb player API JSON
# [youtube] VCbk25eZHwk: Downloading m3u8 information
# Captured frames/VCbk25eZHwk/frame_0.jpg
# Video VCbk25eZHwk captured 1 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=aUKHI1e4prA
# [youtube] aUKHI1e4prA: Downloading webpage
# [youtube] aUKHI1e4prA: Downloading ios player API JSON
# [youtube] aUKHI1e4prA: Downloading mweb player API JSON
# [youtube] aUKHI1e4prA: Downloading m3u8 information
# Captured frames/aUKHI1e4prA/frame_0.jpg
# Captured frames/aUKHI1e4prA/frame_1.jpg
# Captured frames/aUKHI1e4prA/frame_2.jpg
# Video aUKHI1e4prA captured 3 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=tNt4G8dD68I
# [youtube] tNt4G8dD68I: Downloading webpage
# [youtube] tNt4G8dD68I: Downloading ios player API JSON
# [youtube] tNt4G8dD68I: Downloading mweb player API JSON
# [youtube] tNt4G8dD68I: Downloading m3u8 information
# Captured frames/tNt4G8dD68I/frame_0.jpg
# Captured frames/tNt4G8dD68I/frame_1.jpg
# Captured frames/tNt4G8dD68I/frame_2.jpg
# Captured frames/tNt4G8dD68I/frame_3.jpg
# Captured frames/tNt4G8dD68I/frame_4.jpg
# Captured frames/tNt4G8dD68I/frame_5.jpg
# Captured frames/tNt4G8dD68I/frame_6.jpg
# Captured frames/tNt4G8dD68I/frame_7.jpg
# Captured frames/tNt4G8dD68I/frame_8.jpg
# Captured frames/tNt4G8dD68I/frame_9.jpg
# Captured frames/tNt4G8dD68I/frame_10.jpg
# Captured frames/tNt4G8dD68I/frame_11.jpg
# Captured frames/tNt4G8dD68I/frame_12.jpg
# Captured frames/tNt4G8dD68I/frame_13.jpg
# Captured frames/tNt4G8dD68I/frame_14.jpg
# Captured frames/tNt4G8dD68I/frame_15.jpg
# Captured frames/tNt4G8dD68I/frame_16.jpg
# Captured frames/tNt4G8dD68I/frame_17.jpg
# Captured frames/tNt4G8dD68I/frame_18.jpg
# Captured frames/tNt4G8dD68I/frame_19.jpg
# Captured frames/tNt4G8dD68I/frame_20.jpg
# Captured frames/tNt4G8dD68I/frame_21.jpg
# Captured frames/tNt4G8dD68I/frame_22.jpg
# Video tNt4G8dD68I captured 23 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=oGCtcuFL7mk
# [youtube] oGCtcuFL7mk: Downloading webpage
# [youtube] oGCtcuFL7mk: Downloading ios player API JSON
# [youtube] oGCtcuFL7mk: Downloading mweb player API JSON
# [youtube] oGCtcuFL7mk: Downloading m3u8 information
# Captured frames/oGCtcuFL7mk/frame_0.jpg
# Captured frames/oGCtcuFL7mk/frame_1.jpg
# Captured frames/oGCtcuFL7mk/frame_2.jpg
# Video oGCtcuFL7mk captured 3 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=WzgSegP53iM
# [youtube] WzgSegP53iM: Downloading webpage
# [youtube] WzgSegP53iM: Downloading ios player API JSON
# [youtube] WzgSegP53iM: Downloading mweb player API JSON
# [youtube] WzgSegP53iM: Downloading m3u8 information
# Captured frames/WzgSegP53iM/frame_0.jpg
# Video WzgSegP53iM captured 1 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=ZE3hLC3vWvA
# [youtube] ZE3hLC3vWvA: Downloading webpage
# [youtube] ZE3hLC3vWvA: Downloading ios player API JSON
# [youtube] ZE3hLC3vWvA: Downloading mweb player API JSON
# [youtube] ZE3hLC3vWvA: Downloading m3u8 information
# Video ZE3hLC3vWvA captured 0 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Tl1DAzvaWrU
# [youtube] Tl1DAzvaWrU: Downloading webpage
# [youtube] Tl1DAzvaWrU: Downloading ios player API JSON
# [youtube] Tl1DAzvaWrU: Downloading mweb player API JSON
# [youtube] Tl1DAzvaWrU: Downloading m3u8 information
# Captured frames/Tl1DAzvaWrU/frame_0.jpg
# Video Tl1DAzvaWrU captured 1 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=XGhVekgwpH0
# [youtube] XGhVekgwpH0: Downloading webpage
# [youtube] XGhVekgwpH0: Downloading ios player API JSON
# [youtube] XGhVekgwpH0: Downloading mweb player API JSON
# [youtube] XGhVekgwpH0: Downloading m3u8 information
# Captured frames/XGhVekgwpH0/frame_0.jpg
# Captured frames/XGhVekgwpH0/frame_1.jpg
# Captured frames/XGhVekgwpH0/frame_2.jpg
# Captured frames/XGhVekgwpH0/frame_3.jpg
# Captured frames/XGhVekgwpH0/frame_4.jpg
# Captured frames/XGhVekgwpH0/frame_5.jpg
# Video XGhVekgwpH0 captured 6 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=KiSnJZzcr8s
# [youtube] KiSnJZzcr8s: Downloading webpage
# [youtube] KiSnJZzcr8s: Downloading ios player API JSON
# [youtube] KiSnJZzcr8s: Downloading mweb player API JSON
# [youtube] KiSnJZzcr8s: Downloading m3u8 information
# Captured frames/KiSnJZzcr8s/frame_0.jpg
# Captured frames/KiSnJZzcr8s/frame_1.jpg
# Captured frames/KiSnJZzcr8s/frame_2.jpg
# Video KiSnJZzcr8s captured 3 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=XR_dagX3u8Q
# [youtube] XR_dagX3u8Q: Downloading webpage
# [youtube] XR_dagX3u8Q: Downloading ios player API JSON
# [youtube] XR_dagX3u8Q: Downloading mweb player API JSON
# [youtube] XR_dagX3u8Q: Downloading m3u8 information
# Captured frames/XR_dagX3u8Q/frame_0.jpg
# Video XR_dagX3u8Q captured 1 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=wQacyfeP9hM
# [youtube] wQacyfeP9hM: Downloading webpage
# [youtube] wQacyfeP9hM: Downloading ios player API JSON
# [youtube] wQacyfeP9hM: Downloading mweb player API JSON
# [youtube] wQacyfeP9hM: Downloading m3u8 information
# Captured frames/wQacyfeP9hM/frame_0.jpg
# Captured frames/wQacyfeP9hM/frame_1.jpg
# Captured frames/wQacyfeP9hM/frame_2.jpg
# Captured frames/wQacyfeP9hM/frame_3.jpg
# Captured frames/wQacyfeP9hM/frame_4.jpg
# Captured frames/wQacyfeP9hM/frame_5.jpg
# Captured frames/wQacyfeP9hM/frame_6.jpg
# Captured frames/wQacyfeP9hM/frame_7.jpg
# Captured frames/wQacyfeP9hM/frame_8.jpg
# Captured frames/wQacyfeP9hM/frame_9.jpg
# Captured frames/wQacyfeP9hM/frame_10.jpg
# Captured frames/wQacyfeP9hM/frame_11.jpg
# Captured frames/wQacyfeP9hM/frame_12.jpg
# Captured frames/wQacyfeP9hM/frame_13.jpg
# Captured frames/wQacyfeP9hM/frame_14.jpg
# Captured frames/wQacyfeP9hM/frame_15.jpg
# Captured frames/wQacyfeP9hM/frame_16.jpg
# Captured frames/wQacyfeP9hM/frame_17.jpg
# Captured frames/wQacyfeP9hM/frame_18.jpg
# Captured frames/wQacyfeP9hM/frame_19.jpg
# Video wQacyfeP9hM captured 20 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=nR4hh84IfCE
# [youtube] nR4hh84IfCE: Downloading webpage
# [youtube] nR4hh84IfCE: Downloading ios player API JSON
# [youtube] nR4hh84IfCE: Downloading mweb player API JSON
# [youtube] nR4hh84IfCE: Downloading m3u8 information
# Captured frames/nR4hh84IfCE/frame_0.jpg
# Video nR4hh84IfCE captured 1 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=rK2wawuP7M4
# [youtube] rK2wawuP7M4: Downloading webpage
# [youtube] rK2wawuP7M4: Downloading ios player API JSON
# [youtube] rK2wawuP7M4: Downloading mweb player API JSON
# [youtube] rK2wawuP7M4: Downloading m3u8 information
# Captured frames/rK2wawuP7M4/frame_0.jpg
# Captured frames/rK2wawuP7M4/frame_1.jpg
# Captured frames/rK2wawuP7M4/frame_2.jpg
# Captured frames/rK2wawuP7M4/frame_3.jpg
# Captured frames/rK2wawuP7M4/frame_4.jpg
# Video rK2wawuP7M4 captured 5 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=WF7Wfk4Ck58
# [youtube] WF7Wfk4Ck58: Downloading webpage
# [youtube] WF7Wfk4Ck58: Downloading ios player API JSON
# [youtube] WF7Wfk4Ck58: Downloading mweb player API JSON
# [youtube] WF7Wfk4Ck58: Downloading m3u8 information
# Captured frames/WF7Wfk4Ck58/frame_0.jpg
# Captured frames/WF7Wfk4Ck58/frame_1.jpg
# Captured frames/WF7Wfk4Ck58/frame_2.jpg
# Captured frames/WF7Wfk4Ck58/frame_3.jpg
# Captured frames/WF7Wfk4Ck58/frame_4.jpg
# Captured frames/WF7Wfk4Ck58/frame_5.jpg
# Captured frames/WF7Wfk4Ck58/frame_6.jpg
# Captured frames/WF7Wfk4Ck58/frame_7.jpg
# Captured frames/WF7Wfk4Ck58/frame_8.jpg
# Video WF7Wfk4Ck58 captured 9 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=OUlIleUZomI
# [youtube] OUlIleUZomI: Downloading webpage
# [youtube] OUlIleUZomI: Downloading ios player API JSON
# [youtube] OUlIleUZomI: Downloading mweb player API JSON
# [youtube] OUlIleUZomI: Downloading m3u8 information
# Captured frames/OUlIleUZomI/frame_0.jpg
# Captured frames/OUlIleUZomI/frame_1.jpg
# Captured frames/OUlIleUZomI/frame_2.jpg
# Captured frames/OUlIleUZomI/frame_3.jpg
# Captured frames/OUlIleUZomI/frame_4.jpg
# Captured frames/OUlIleUZomI/frame_5.jpg
# Captured frames/OUlIleUZomI/frame_6.jpg
# Video OUlIleUZomI captured 7 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=0OjGV_YTHZM
# [youtube] 0OjGV_YTHZM: Downloading webpage
# [youtube] 0OjGV_YTHZM: Downloading ios player API JSON
# [youtube] 0OjGV_YTHZM: Downloading mweb player API JSON
# [youtube] 0OjGV_YTHZM: Downloading m3u8 information
# Captured frames/0OjGV_YTHZM/frame_0.jpg
# Captured frames/0OjGV_YTHZM/frame_1.jpg
# Captured frames/0OjGV_YTHZM/frame_2.jpg
# Captured frames/0OjGV_YTHZM/frame_3.jpg
# Captured frames/0OjGV_YTHZM/frame_4.jpg
# Captured frames/0OjGV_YTHZM/frame_5.jpg
# Captured frames/0OjGV_YTHZM/frame_6.jpg
# Captured frames/0OjGV_YTHZM/frame_7.jpg
# Captured frames/0OjGV_YTHZM/frame_8.jpg
# Captured frames/0OjGV_YTHZM/frame_9.jpg
# Captured frames/0OjGV_YTHZM/frame_10.jpg
# Captured frames/0OjGV_YTHZM/frame_11.jpg
# Captured frames/0OjGV_YTHZM/frame_12.jpg
# Captured frames/0OjGV_YTHZM/frame_13.jpg
# Captured frames/0OjGV_YTHZM/frame_14.jpg
# Captured frames/0OjGV_YTHZM/frame_15.jpg
# Captured frames/0OjGV_YTHZM/frame_16.jpg
# Captured frames/0OjGV_YTHZM/frame_17.jpg
# Captured frames/0OjGV_YTHZM/frame_18.jpg
# Captured frames/0OjGV_YTHZM/frame_19.jpg
# Captured frames/0OjGV_YTHZM/frame_20.jpg
# Captured frames/0OjGV_YTHZM/frame_21.jpg
# Captured frames/0OjGV_YTHZM/frame_22.jpg
# Captured frames/0OjGV_YTHZM/frame_23.jpg
# Captured frames/0OjGV_YTHZM/frame_24.jpg
# Captured frames/0OjGV_YTHZM/frame_25.jpg
# Captured frames/0OjGV_YTHZM/frame_26.jpg
# Captured frames/0OjGV_YTHZM/frame_27.jpg
# Captured frames/0OjGV_YTHZM/frame_28.jpg
# Captured frames/0OjGV_YTHZM/frame_29.jpg
# Captured frames/0OjGV_YTHZM/frame_30.jpg
# Captured frames/0OjGV_YTHZM/frame_31.jpg
# Captured frames/0OjGV_YTHZM/frame_32.jpg
# Captured frames/0OjGV_YTHZM/frame_33.jpg
# Captured frames/0OjGV_YTHZM/frame_34.jpg
# Captured frames/0OjGV_YTHZM/frame_35.jpg
# Captured frames/0OjGV_YTHZM/frame_36.jpg
# Captured frames/0OjGV_YTHZM/frame_37.jpg
# Captured frames/0OjGV_YTHZM/frame_38.jpg
# Captured frames/0OjGV_YTHZM/frame_39.jpg
# Captured frames/0OjGV_YTHZM/frame_40.jpg
# Captured frames/0OjGV_YTHZM/frame_41.jpg
# Captured frames/0OjGV_YTHZM/frame_42.jpg
# Captured frames/0OjGV_YTHZM/frame_43.jpg
# Captured frames/0OjGV_YTHZM/frame_44.jpg
# Captured frames/0OjGV_YTHZM/frame_45.jpg
# Captured frames/0OjGV_YTHZM/frame_46.jpg
# Captured frames/0OjGV_YTHZM/frame_47.jpg
# Captured frames/0OjGV_YTHZM/frame_48.jpg
# Captured frames/0OjGV_YTHZM/frame_49.jpg
# Captured frames/0OjGV_YTHZM/frame_50.jpg
# Captured frames/0OjGV_YTHZM/frame_51.jpg
# Captured frames/0OjGV_YTHZM/frame_52.jpg
# Captured frames/0OjGV_YTHZM/frame_53.jpg
# Captured frames/0OjGV_YTHZM/frame_54.jpg
# Captured frames/0OjGV_YTHZM/frame_55.jpg
# Captured frames/0OjGV_YTHZM/frame_56.jpg
# Captured frames/0OjGV_YTHZM/frame_57.jpg
# Video 0OjGV_YTHZM captured 58 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=snd-ldpvQS8
# [youtube] snd-ldpvQS8: Downloading webpage
# [youtube] snd-ldpvQS8: Downloading ios player API JSON
# [youtube] snd-ldpvQS8: Downloading mweb player API JSON
# [youtube] snd-ldpvQS8: Downloading m3u8 information
# Captured frames/snd-ldpvQS8/frame_0.jpg
# Captured frames/snd-ldpvQS8/frame_1.jpg
# Captured frames/snd-ldpvQS8/frame_2.jpg
# Captured frames/snd-ldpvQS8/frame_3.jpg
# Captured frames/snd-ldpvQS8/frame_4.jpg
# Captured frames/snd-ldpvQS8/frame_5.jpg
# Captured frames/snd-ldpvQS8/frame_6.jpg
# Video snd-ldpvQS8 captured 7 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=mdXtetxn8sI
# [youtube] mdXtetxn8sI: Downloading webpage
# [youtube] mdXtetxn8sI: Downloading ios player API JSON
# [youtube] mdXtetxn8sI: Downloading mweb player API JSON
# [youtube] mdXtetxn8sI: Downloading m3u8 information
# Captured frames/mdXtetxn8sI/frame_0.jpg
# Captured frames/mdXtetxn8sI/frame_1.jpg
# Captured frames/mdXtetxn8sI/frame_2.jpg
# Captured frames/mdXtetxn8sI/frame_3.jpg
# Captured frames/mdXtetxn8sI/frame_4.jpg
# Captured frames/mdXtetxn8sI/frame_5.jpg
# Captured frames/mdXtetxn8sI/frame_6.jpg
# Captured frames/mdXtetxn8sI/frame_7.jpg
# Captured frames/mdXtetxn8sI/frame_8.jpg
# Captured frames/mdXtetxn8sI/frame_9.jpg
# Video mdXtetxn8sI captured 10 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=gy4h8-1FDvg
# [youtube] gy4h8-1FDvg: Downloading webpage
# [youtube] gy4h8-1FDvg: Downloading ios player API JSON
# [youtube] gy4h8-1FDvg: Downloading mweb player API JSON
# [youtube] gy4h8-1FDvg: Downloading m3u8 information
# Video gy4h8-1FDvg captured 0 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Okp0pfExsHc
# [youtube] Okp0pfExsHc: Downloading webpage
# [youtube] Okp0pfExsHc: Downloading ios player API JSON
# [youtube] Okp0pfExsHc: Downloading mweb player API JSON
# [youtube] Okp0pfExsHc: Downloading m3u8 information
# Captured frames/Okp0pfExsHc/frame_0.jpg
# Captured frames/Okp0pfExsHc/frame_1.jpg
# Captured frames/Okp0pfExsHc/frame_2.jpg
# Captured frames/Okp0pfExsHc/frame_3.jpg
# Captured frames/Okp0pfExsHc/frame_4.jpg
# Captured frames/Okp0pfExsHc/frame_5.jpg
# Captured frames/Okp0pfExsHc/frame_6.jpg
# Captured frames/Okp0pfExsHc/frame_7.jpg
# Captured frames/Okp0pfExsHc/frame_8.jpg
# Captured frames/Okp0pfExsHc/frame_9.jpg
# Captured frames/Okp0pfExsHc/frame_10.jpg
# Captured frames/Okp0pfExsHc/frame_11.jpg
# Captured frames/Okp0pfExsHc/frame_12.jpg
# Captured frames/Okp0pfExsHc/frame_13.jpg
# Captured frames/Okp0pfExsHc/frame_14.jpg
# Captured frames/Okp0pfExsHc/frame_15.jpg
# Captured frames/Okp0pfExsHc/frame_16.jpg
# Captured frames/Okp0pfExsHc/frame_17.jpg
# Captured frames/Okp0pfExsHc/frame_18.jpg
# Video Okp0pfExsHc captured 19 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=mgDzhOREYDo
# [youtube] mgDzhOREYDo: Downloading webpage
# [youtube] mgDzhOREYDo: Downloading ios player API JSON
# [youtube] mgDzhOREYDo: Downloading mweb player API JSON
# [youtube] mgDzhOREYDo: Downloading m3u8 information
# Video mgDzhOREYDo captured 0 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Nfs_6UlkgTk
# [youtube] Nfs_6UlkgTk: Downloading webpage
# [youtube] Nfs_6UlkgTk: Downloading ios player API JSON
# [youtube] Nfs_6UlkgTk: Downloading mweb player API JSON
# [youtube] Nfs_6UlkgTk: Downloading m3u8 information
# Captured frames/Nfs_6UlkgTk/frame_0.jpg
# Video Nfs_6UlkgTk captured 1 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=hA7RH_TE0yY
# [youtube] hA7RH_TE0yY: Downloading webpage
# [youtube] hA7RH_TE0yY: Downloading ios player API JSON
# [youtube] hA7RH_TE0yY: Downloading mweb player API JSON
# [youtube] hA7RH_TE0yY: Downloading m3u8 information
# Video hA7RH_TE0yY captured 0 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=N5AH-9bPi1c
# [youtube] N5AH-9bPi1c: Downloading webpage
# [youtube] N5AH-9bPi1c: Downloading ios player API JSON
# [youtube] N5AH-9bPi1c: Downloading mweb player API JSON
# [youtube] N5AH-9bPi1c: Downloading m3u8 information
# Captured frames/N5AH-9bPi1c/frame_0.jpg
# Video N5AH-9bPi1c captured 1 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Ajc2G06QTak
# [youtube] Ajc2G06QTak: Downloading webpage
# [youtube] Ajc2G06QTak: Downloading ios player API JSON
# [youtube] Ajc2G06QTak: Downloading mweb player API JSON
# [youtube] Ajc2G06QTak: Downloading m3u8 information
# Captured frames/Ajc2G06QTak/frame_0.jpg
# Video Ajc2G06QTak captured 1 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=d8Pcsj9UVgA
# [youtube] d8Pcsj9UVgA: Downloading webpage
# [youtube] d8Pcsj9UVgA: Downloading ios player API JSON
# [youtube] d8Pcsj9UVgA: Downloading mweb player API JSON
# [youtube] d8Pcsj9UVgA: Downloading m3u8 information
# Captured frames/d8Pcsj9UVgA/frame_0.jpg
# Captured frames/d8Pcsj9UVgA/frame_1.jpg
# Captured frames/d8Pcsj9UVgA/frame_2.jpg
# Captured frames/d8Pcsj9UVgA/frame_3.jpg
# Captured frames/d8Pcsj9UVgA/frame_4.jpg
# Captured frames/d8Pcsj9UVgA/frame_5.jpg
# Captured frames/d8Pcsj9UVgA/frame_6.jpg
# Captured frames/d8Pcsj9UVgA/frame_7.jpg
# Captured frames/d8Pcsj9UVgA/frame_8.jpg
# Captured frames/d8Pcsj9UVgA/frame_9.jpg
# Captured frames/d8Pcsj9UVgA/frame_10.jpg
# Captured frames/d8Pcsj9UVgA/frame_11.jpg
# Video d8Pcsj9UVgA captured 12 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=-dveQ64KgAY
# [youtube] -dveQ64KgAY: Downloading webpage
# [youtube] -dveQ64KgAY: Downloading ios player API JSON
# [youtube] -dveQ64KgAY: Downloading mweb player API JSON
# [youtube] -dveQ64KgAY: Downloading m3u8 information
# Captured frames/-dveQ64KgAY/frame_0.jpg
# Video -dveQ64KgAY captured 1 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=n6PKvV809NU
# [youtube] n6PKvV809NU: Downloading webpage
# [youtube] n6PKvV809NU: Downloading ios player API JSON
# [youtube] n6PKvV809NU: Downloading mweb player API JSON
# [youtube] n6PKvV809NU: Downloading m3u8 information
# Captured frames/n6PKvV809NU/frame_0.jpg
# Video n6PKvV809NU captured 1 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=fZzCmc6oBZA
# [youtube] fZzCmc6oBZA: Downloading webpage
# [youtube] fZzCmc6oBZA: Downloading ios player API JSON
# [youtube] fZzCmc6oBZA: Downloading mweb player API JSON
# [youtube] fZzCmc6oBZA: Downloading m3u8 information
# Captured frames/fZzCmc6oBZA/frame_0.jpg
# Captured frames/fZzCmc6oBZA/frame_1.jpg
# Captured frames/fZzCmc6oBZA/frame_2.jpg
# Captured frames/fZzCmc6oBZA/frame_3.jpg
# Captured frames/fZzCmc6oBZA/frame_4.jpg
# Captured frames/fZzCmc6oBZA/frame_5.jpg
# Captured frames/fZzCmc6oBZA/frame_6.jpg
# Captured frames/fZzCmc6oBZA/frame_7.jpg
# Captured frames/fZzCmc6oBZA/frame_8.jpg
# Captured frames/fZzCmc6oBZA/frame_9.jpg
# Captured frames/fZzCmc6oBZA/frame_10.jpg
# Captured frames/fZzCmc6oBZA/frame_11.jpg
# Captured frames/fZzCmc6oBZA/frame_12.jpg
# Captured frames/fZzCmc6oBZA/frame_13.jpg
# Captured frames/fZzCmc6oBZA/frame_14.jpg
# Captured frames/fZzCmc6oBZA/frame_15.jpg
# Captured frames/fZzCmc6oBZA/frame_16.jpg
# Captured frames/fZzCmc6oBZA/frame_17.jpg
# Captured frames/fZzCmc6oBZA/frame_18.jpg
# Captured frames/fZzCmc6oBZA/frame_19.jpg
# Captured frames/fZzCmc6oBZA/frame_20.jpg
# Captured frames/fZzCmc6oBZA/frame_21.jpg
# Captured frames/fZzCmc6oBZA/frame_22.jpg
# Captured frames/fZzCmc6oBZA/frame_23.jpg
# Captured frames/fZzCmc6oBZA/frame_24.jpg
# Captured frames/fZzCmc6oBZA/frame_25.jpg
# Captured frames/fZzCmc6oBZA/frame_26.jpg
# Captured frames/fZzCmc6oBZA/frame_27.jpg
# Captured frames/fZzCmc6oBZA/frame_28.jpg
# Captured frames/fZzCmc6oBZA/frame_29.jpg
# Captured frames/fZzCmc6oBZA/frame_30.jpg
# Captured frames/fZzCmc6oBZA/frame_31.jpg
# Captured frames/fZzCmc6oBZA/frame_32.jpg
# Captured frames/fZzCmc6oBZA/frame_33.jpg
# Captured frames/fZzCmc6oBZA/frame_34.jpg
# Captured frames/fZzCmc6oBZA/frame_35.jpg
# Captured frames/fZzCmc6oBZA/frame_36.jpg
# Captured frames/fZzCmc6oBZA/frame_37.jpg
# Captured frames/fZzCmc6oBZA/frame_38.jpg
# Captured frames/fZzCmc6oBZA/frame_39.jpg
# Captured frames/fZzCmc6oBZA/frame_40.jpg
# Captured frames/fZzCmc6oBZA/frame_41.jpg
# Captured frames/fZzCmc6oBZA/frame_42.jpg
# Captured frames/fZzCmc6oBZA/frame_43.jpg
# Captured frames/fZzCmc6oBZA/frame_44.jpg
# Captured frames/fZzCmc6oBZA/frame_45.jpg
# Captured frames/fZzCmc6oBZA/frame_46.jpg
# Captured frames/fZzCmc6oBZA/frame_47.jpg
# Captured frames/fZzCmc6oBZA/frame_48.jpg
# Captured frames/fZzCmc6oBZA/frame_49.jpg
# Captured frames/fZzCmc6oBZA/frame_50.jpg
# Captured frames/fZzCmc6oBZA/frame_51.jpg
# Captured frames/fZzCmc6oBZA/frame_52.jpg
# Captured frames/fZzCmc6oBZA/frame_53.jpg
# Captured frames/fZzCmc6oBZA/frame_54.jpg
# Captured frames/fZzCmc6oBZA/frame_55.jpg
# Captured frames/fZzCmc6oBZA/frame_56.jpg
# Captured frames/fZzCmc6oBZA/frame_57.jpg
# Captured frames/fZzCmc6oBZA/frame_58.jpg
# Captured frames/fZzCmc6oBZA/frame_59.jpg
# Video fZzCmc6oBZA captured 60 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=47HvI2fklQE
# [youtube] 47HvI2fklQE: Downloading webpage
# [youtube] 47HvI2fklQE: Downloading ios player API JSON
# [youtube] 47HvI2fklQE: Downloading mweb player API JSON
# [youtube] 47HvI2fklQE: Downloading m3u8 information
# Video 47HvI2fklQE captured 0 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=JSLLYMICrCQ
# [youtube] JSLLYMICrCQ: Downloading webpage
# [youtube] JSLLYMICrCQ: Downloading ios player API JSON
# [youtube] JSLLYMICrCQ: Downloading mweb player API JSON
# [youtube] JSLLYMICrCQ: Downloading m3u8 information
# Captured frames/JSLLYMICrCQ/frame_0.jpg
# Captured frames/JSLLYMICrCQ/frame_1.jpg
# Video JSLLYMICrCQ captured 2 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=gBR9BkBlTMc
# [youtube] gBR9BkBlTMc: Downloading webpage
# [youtube] gBR9BkBlTMc: Downloading ios player API JSON
# [youtube] gBR9BkBlTMc: Downloading mweb player API JSON
# [youtube] gBR9BkBlTMc: Downloading m3u8 information
# Captured frames/gBR9BkBlTMc/frame_0.jpg
# Captured frames/gBR9BkBlTMc/frame_1.jpg
# Captured frames/gBR9BkBlTMc/frame_2.jpg
# Captured frames/gBR9BkBlTMc/frame_3.jpg
# Captured frames/gBR9BkBlTMc/frame_4.jpg
# Captured frames/gBR9BkBlTMc/frame_5.jpg
# Captured frames/gBR9BkBlTMc/frame_6.jpg
# Captured frames/gBR9BkBlTMc/frame_7.jpg
# Captured frames/gBR9BkBlTMc/frame_8.jpg
# Captured frames/gBR9BkBlTMc/frame_9.jpg
# Captured frames/gBR9BkBlTMc/frame_10.jpg
# Captured frames/gBR9BkBlTMc/frame_11.jpg
# Captured frames/gBR9BkBlTMc/frame_12.jpg
# Captured frames/gBR9BkBlTMc/frame_13.jpg
# Captured frames/gBR9BkBlTMc/frame_14.jpg
# Captured frames/gBR9BkBlTMc/frame_15.jpg
# Captured frames/gBR9BkBlTMc/frame_16.jpg
# Captured frames/gBR9BkBlTMc/frame_17.jpg
# Captured frames/gBR9BkBlTMc/frame_18.jpg
# Captured frames/gBR9BkBlTMc/frame_19.jpg
# Captured frames/gBR9BkBlTMc/frame_20.jpg
# Captured frames/gBR9BkBlTMc/frame_21.jpg
# Captured frames/gBR9BkBlTMc/frame_22.jpg
# Captured frames/gBR9BkBlTMc/frame_23.jpg
# Captured frames/gBR9BkBlTMc/frame_24.jpg
# Captured frames/gBR9BkBlTMc/frame_25.jpg
# Captured frames/gBR9BkBlTMc/frame_26.jpg
# Captured frames/gBR9BkBlTMc/frame_27.jpg
# Captured frames/gBR9BkBlTMc/frame_28.jpg
# Captured frames/gBR9BkBlTMc/frame_29.jpg
# Captured frames/gBR9BkBlTMc/frame_30.jpg
# Captured frames/gBR9BkBlTMc/frame_31.jpg
# Captured frames/gBR9BkBlTMc/frame_32.jpg
# Captured frames/gBR9BkBlTMc/frame_33.jpg
# Captured frames/gBR9BkBlTMc/frame_34.jpg
# Captured frames/gBR9BkBlTMc/frame_35.jpg
# Video gBR9BkBlTMc captured 36 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=bAnwZppza60
# [youtube] bAnwZppza60: Downloading webpage
# [youtube] bAnwZppza60: Downloading ios player API JSON
# [youtube] bAnwZppza60: Downloading mweb player API JSON
# [youtube] bAnwZppza60: Downloading m3u8 information
# Captured frames/bAnwZppza60/frame_0.jpg
# Captured frames/bAnwZppza60/frame_1.jpg
# Captured frames/bAnwZppza60/frame_2.jpg
# Captured frames/bAnwZppza60/frame_3.jpg
# Video bAnwZppza60 captured 4 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=66DxiycOm1g
# [youtube] 66DxiycOm1g: Downloading webpage
# [youtube] 66DxiycOm1g: Downloading ios player API JSON
# [youtube] 66DxiycOm1g: Downloading mweb player API JSON
# [youtube] 66DxiycOm1g: Downloading m3u8 information
# Captured frames/66DxiycOm1g/frame_0.jpg
# Video 66DxiycOm1g captured 1 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=HLGi5WRcsaw
# [youtube] HLGi5WRcsaw: Downloading webpage
# [youtube] HLGi5WRcsaw: Downloading ios player API JSON
# [youtube] HLGi5WRcsaw: Downloading mweb player API JSON
# [youtube] HLGi5WRcsaw: Downloading m3u8 information
# Captured frames/HLGi5WRcsaw/frame_0.jpg
# Captured frames/HLGi5WRcsaw/frame_1.jpg
# Video HLGi5WRcsaw captured 2 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=tMsf6i7yID8
# [youtube] tMsf6i7yID8: Downloading webpage
# [youtube] tMsf6i7yID8: Downloading ios player API JSON
# [youtube] tMsf6i7yID8: Downloading mweb player API JSON
# [youtube] tMsf6i7yID8: Downloading m3u8 information
# Captured frames/tMsf6i7yID8/frame_0.jpg
# Captured frames/tMsf6i7yID8/frame_1.jpg
# Captured frames/tMsf6i7yID8/frame_2.jpg
# Captured frames/tMsf6i7yID8/frame_3.jpg
# Captured frames/tMsf6i7yID8/frame_4.jpg
# Captured frames/tMsf6i7yID8/frame_5.jpg
# Captured frames/tMsf6i7yID8/frame_6.jpg
# Captured frames/tMsf6i7yID8/frame_7.jpg
# Captured frames/tMsf6i7yID8/frame_8.jpg
# Captured frames/tMsf6i7yID8/frame_9.jpg
# Captured frames/tMsf6i7yID8/frame_10.jpg
# Video tMsf6i7yID8 captured 11 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=UT6ENscdDm4
# [youtube] UT6ENscdDm4: Downloading webpage
# [youtube] UT6ENscdDm4: Downloading ios player API JSON
# [youtube] UT6ENscdDm4: Downloading mweb player API JSON
# [youtube] UT6ENscdDm4: Downloading m3u8 information
# Captured frames/UT6ENscdDm4/frame_0.jpg
# Captured frames/UT6ENscdDm4/frame_1.jpg
# Video UT6ENscdDm4 captured 2 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=nIFnd0XDlsU
# [youtube] nIFnd0XDlsU: Downloading webpage
# [youtube] nIFnd0XDlsU: Downloading ios player API JSON
# [youtube] nIFnd0XDlsU: Downloading mweb player API JSON
# [youtube] nIFnd0XDlsU: Downloading m3u8 information
# Video nIFnd0XDlsU captured 0 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=8ObHgWdjcf0
# [youtube] 8ObHgWdjcf0: Downloading webpage
# [youtube] 8ObHgWdjcf0: Downloading ios player API JSON
# [youtube] 8ObHgWdjcf0: Downloading mweb player API JSON
# [youtube] 8ObHgWdjcf0: Downloading m3u8 information
# Video 8ObHgWdjcf0 captured 0 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=40rhzwOPt68
# [youtube] 40rhzwOPt68: Downloading webpage
# [youtube] 40rhzwOPt68: Downloading ios player API JSON
# [youtube] 40rhzwOPt68: Downloading mweb player API JSON
# [youtube] 40rhzwOPt68: Downloading m3u8 information
# Captured frames/40rhzwOPt68/frame_0.jpg
# Captured frames/40rhzwOPt68/frame_1.jpg
# Captured frames/40rhzwOPt68/frame_2.jpg
# Captured frames/40rhzwOPt68/frame_3.jpg
# Captured frames/40rhzwOPt68/frame_4.jpg
# Captured frames/40rhzwOPt68/frame_5.jpg
# Captured frames/40rhzwOPt68/frame_6.jpg
# Captured frames/40rhzwOPt68/frame_7.jpg
# Captured frames/40rhzwOPt68/frame_8.jpg
# Captured frames/40rhzwOPt68/frame_9.jpg
# Captured frames/40rhzwOPt68/frame_10.jpg
# Captured frames/40rhzwOPt68/frame_11.jpg
# Captured frames/40rhzwOPt68/frame_12.jpg
# Captured frames/40rhzwOPt68/frame_13.jpg
# Captured frames/40rhzwOPt68/frame_14.jpg
# Captured frames/40rhzwOPt68/frame_15.jpg
# Captured frames/40rhzwOPt68/frame_16.jpg
# Captured frames/40rhzwOPt68/frame_17.jpg
# Captured frames/40rhzwOPt68/frame_18.jpg
# Captured frames/40rhzwOPt68/frame_19.jpg
# Captured frames/40rhzwOPt68/frame_20.jpg
# Captured frames/40rhzwOPt68/frame_21.jpg
# Captured frames/40rhzwOPt68/frame_22.jpg
# Captured frames/40rhzwOPt68/frame_23.jpg
# Captured frames/40rhzwOPt68/frame_24.jpg
# Captured frames/40rhzwOPt68/frame_25.jpg
# Captured frames/40rhzwOPt68/frame_26.jpg
# Captured frames/40rhzwOPt68/frame_27.jpg
# Captured frames/40rhzwOPt68/frame_28.jpg
# Captured frames/40rhzwOPt68/frame_29.jpg
# Captured frames/40rhzwOPt68/frame_30.jpg
# Captured frames/40rhzwOPt68/frame_31.jpg
# Captured frames/40rhzwOPt68/frame_32.jpg
# Captured frames/40rhzwOPt68/frame_33.jpg
# Captured frames/40rhzwOPt68/frame_34.jpg
# Captured frames/40rhzwOPt68/frame_35.jpg
# Captured frames/40rhzwOPt68/frame_36.jpg
# Captured frames/40rhzwOPt68/frame_37.jpg
# Captured frames/40rhzwOPt68/frame_38.jpg
# Captured frames/40rhzwOPt68/frame_39.jpg
# Captured frames/40rhzwOPt68/frame_40.jpg
# Captured frames/40rhzwOPt68/frame_41.jpg
# Captured frames/40rhzwOPt68/frame_42.jpg
# Captured frames/40rhzwOPt68/frame_43.jpg
# Captured frames/40rhzwOPt68/frame_44.jpg
# Captured frames/40rhzwOPt68/frame_45.jpg
# Captured frames/40rhzwOPt68/frame_46.jpg
# Captured frames/40rhzwOPt68/frame_47.jpg
# Captured frames/40rhzwOPt68/frame_48.jpg
# Captured frames/40rhzwOPt68/frame_49.jpg
# Captured frames/40rhzwOPt68/frame_50.jpg
# Captured frames/40rhzwOPt68/frame_51.jpg
# Captured frames/40rhzwOPt68/frame_52.jpg
# Captured frames/40rhzwOPt68/frame_53.jpg
# Captured frames/40rhzwOPt68/frame_54.jpg
# Captured frames/40rhzwOPt68/frame_55.jpg
# Video 40rhzwOPt68 captured 56 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=IejrSjoDOhU
# [youtube] IejrSjoDOhU: Downloading webpage
# [youtube] IejrSjoDOhU: Downloading ios player API JSON
# [youtube] IejrSjoDOhU: Downloading mweb player API JSON
# [youtube] IejrSjoDOhU: Downloading m3u8 information
# Captured frames/IejrSjoDOhU/frame_0.jpg
# Captured frames/IejrSjoDOhU/frame_1.jpg
# Captured frames/IejrSjoDOhU/frame_2.jpg
# Captured frames/IejrSjoDOhU/frame_3.jpg
# Captured frames/IejrSjoDOhU/frame_4.jpg
# Captured frames/IejrSjoDOhU/frame_5.jpg
# Captured frames/IejrSjoDOhU/frame_6.jpg
# Captured frames/IejrSjoDOhU/frame_7.jpg
# Captured frames/IejrSjoDOhU/frame_8.jpg
# Captured frames/IejrSjoDOhU/frame_9.jpg
# Captured frames/IejrSjoDOhU/frame_10.jpg
# Captured frames/IejrSjoDOhU/frame_11.jpg
# Captured frames/IejrSjoDOhU/frame_12.jpg
# Captured frames/IejrSjoDOhU/frame_13.jpg
# Captured frames/IejrSjoDOhU/frame_14.jpg
# Captured frames/IejrSjoDOhU/frame_15.jpg
# Captured frames/IejrSjoDOhU/frame_16.jpg
# Captured frames/IejrSjoDOhU/frame_17.jpg
# Captured frames/IejrSjoDOhU/frame_18.jpg
# Captured frames/IejrSjoDOhU/frame_19.jpg
# Captured frames/IejrSjoDOhU/frame_20.jpg
# Captured frames/IejrSjoDOhU/frame_21.jpg
# Captured frames/IejrSjoDOhU/frame_22.jpg
# Captured frames/IejrSjoDOhU/frame_23.jpg
# Captured frames/IejrSjoDOhU/frame_24.jpg
# Captured frames/IejrSjoDOhU/frame_25.jpg
# Captured frames/IejrSjoDOhU/frame_26.jpg
# Captured frames/IejrSjoDOhU/frame_27.jpg
# Captured frames/IejrSjoDOhU/frame_28.jpg
# Captured frames/IejrSjoDOhU/frame_29.jpg
# Captured frames/IejrSjoDOhU/frame_30.jpg
# Captured frames/IejrSjoDOhU/frame_31.jpg
# Captured frames/IejrSjoDOhU/frame_32.jpg
# Captured frames/IejrSjoDOhU/frame_33.jpg
# Captured frames/IejrSjoDOhU/frame_34.jpg
# Captured frames/IejrSjoDOhU/frame_35.jpg
# Captured frames/IejrSjoDOhU/frame_36.jpg
# Captured frames/IejrSjoDOhU/frame_37.jpg
# Captured frames/IejrSjoDOhU/frame_38.jpg
# Captured frames/IejrSjoDOhU/frame_39.jpg
# Captured frames/IejrSjoDOhU/frame_40.jpg
# Captured frames/IejrSjoDOhU/frame_41.jpg
# Captured frames/IejrSjoDOhU/frame_42.jpg
# Captured frames/IejrSjoDOhU/frame_43.jpg
# Captured frames/IejrSjoDOhU/frame_44.jpg
# Captured frames/IejrSjoDOhU/frame_45.jpg
# Captured frames/IejrSjoDOhU/frame_46.jpg
# Captured frames/IejrSjoDOhU/frame_47.jpg
# Captured frames/IejrSjoDOhU/frame_48.jpg
# Captured frames/IejrSjoDOhU/frame_49.jpg
# Captured frames/IejrSjoDOhU/frame_50.jpg
# Captured frames/IejrSjoDOhU/frame_51.jpg
# Captured frames/IejrSjoDOhU/frame_52.jpg
# Captured frames/IejrSjoDOhU/frame_53.jpg
# Captured frames/IejrSjoDOhU/frame_54.jpg
# Captured frames/IejrSjoDOhU/frame_55.jpg
# Captured frames/IejrSjoDOhU/frame_56.jpg
# Captured frames/IejrSjoDOhU/frame_57.jpg
# Captured frames/IejrSjoDOhU/frame_58.jpg
# Captured frames/IejrSjoDOhU/frame_59.jpg
# Captured frames/IejrSjoDOhU/frame_60.jpg
# Captured frames/IejrSjoDOhU/frame_61.jpg
# Captured frames/IejrSjoDOhU/frame_62.jpg
# Captured frames/IejrSjoDOhU/frame_63.jpg
# Captured frames/IejrSjoDOhU/frame_64.jpg
# Captured frames/IejrSjoDOhU/frame_65.jpg
# Captured frames/IejrSjoDOhU/frame_66.jpg
# Captured frames/IejrSjoDOhU/frame_67.jpg
# Captured frames/IejrSjoDOhU/frame_68.jpg
# Captured frames/IejrSjoDOhU/frame_69.jpg
# Captured frames/IejrSjoDOhU/frame_70.jpg
# Captured frames/IejrSjoDOhU/frame_71.jpg
# Captured frames/IejrSjoDOhU/frame_72.jpg
# Captured frames/IejrSjoDOhU/frame_73.jpg
# Captured frames/IejrSjoDOhU/frame_74.jpg
# Video IejrSjoDOhU captured 75 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=giddV9T7G4c
# [youtube] giddV9T7G4c: Downloading webpage
# [youtube] giddV9T7G4c: Downloading ios player API JSON
# [youtube] giddV9T7G4c: Downloading mweb player API JSON
# [youtube] giddV9T7G4c: Downloading m3u8 information
# Captured frames/giddV9T7G4c/frame_0.jpg
# Captured frames/giddV9T7G4c/frame_1.jpg
# Captured frames/giddV9T7G4c/frame_2.jpg
# Video giddV9T7G4c captured 3 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=YiF4oNhvsfY
# [youtube] YiF4oNhvsfY: Downloading webpage
# [youtube] YiF4oNhvsfY: Downloading ios player API JSON
# [youtube] YiF4oNhvsfY: Downloading mweb player API JSON
# [youtube] YiF4oNhvsfY: Downloading m3u8 information
# Captured frames/YiF4oNhvsfY/frame_0.jpg
# Captured frames/YiF4oNhvsfY/frame_1.jpg
# Video YiF4oNhvsfY captured 2 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=fkzMk7SpOC0
# [youtube] fkzMk7SpOC0: Downloading webpage
# [youtube] fkzMk7SpOC0: Downloading ios player API JSON
# [youtube] fkzMk7SpOC0: Downloading mweb player API JSON
# [youtube] fkzMk7SpOC0: Downloading m3u8 information
# Captured frames/fkzMk7SpOC0/frame_0.jpg
# Video fkzMk7SpOC0 captured 1 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=9cY7WoZrK3A
# [youtube] 9cY7WoZrK3A: Downloading webpage
# [youtube] 9cY7WoZrK3A: Downloading ios player API JSON
# [youtube] 9cY7WoZrK3A: Downloading mweb player API JSON
# [youtube] 9cY7WoZrK3A: Downloading m3u8 information
# [youtube] 9cY7WoZrK3A: Downloading MPD manifest
# Captured frames/9cY7WoZrK3A/frame_0.jpg
# Video 9cY7WoZrK3A captured 1 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=ONlgF8jTUsM
# [youtube] ONlgF8jTUsM: Downloading webpage
# [youtube] ONlgF8jTUsM: Downloading ios player API JSON
# [youtube] ONlgF8jTUsM: Downloading mweb player API JSON
# [youtube] ONlgF8jTUsM: Downloading m3u8 information
# Captured frames/ONlgF8jTUsM/frame_0.jpg
# Captured frames/ONlgF8jTUsM/frame_1.jpg
# Captured frames/ONlgF8jTUsM/frame_2.jpg
# Captured frames/ONlgF8jTUsM/frame_3.jpg
# Captured frames/ONlgF8jTUsM/frame_4.jpg
# Captured frames/ONlgF8jTUsM/frame_5.jpg
# Captured frames/ONlgF8jTUsM/frame_6.jpg
# Captured frames/ONlgF8jTUsM/frame_7.jpg
# Video ONlgF8jTUsM captured 8 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=aoL-CuvX5C8
# [youtube] aoL-CuvX5C8: Downloading webpage
# [youtube] aoL-CuvX5C8: Downloading ios player API JSON
# [youtube] aoL-CuvX5C8: Downloading mweb player API JSON
# [youtube] aoL-CuvX5C8: Downloading m3u8 information
# Captured frames/aoL-CuvX5C8/frame_0.jpg
# Captured frames/aoL-CuvX5C8/frame_1.jpg
# Captured frames/aoL-CuvX5C8/frame_2.jpg
# Captured frames/aoL-CuvX5C8/frame_3.jpg
# Captured frames/aoL-CuvX5C8/frame_4.jpg
# Captured frames/aoL-CuvX5C8/frame_5.jpg
# Captured frames/aoL-CuvX5C8/frame_6.jpg
# Captured frames/aoL-CuvX5C8/frame_7.jpg
# Captured frames/aoL-CuvX5C8/frame_8.jpg
# Captured frames/aoL-CuvX5C8/frame_9.jpg
# Captured frames/aoL-CuvX5C8/frame_10.jpg
# Captured frames/aoL-CuvX5C8/frame_11.jpg
# Captured frames/aoL-CuvX5C8/frame_12.jpg
# Captured frames/aoL-CuvX5C8/frame_13.jpg
# Captured frames/aoL-CuvX5C8/frame_14.jpg
# Captured frames/aoL-CuvX5C8/frame_15.jpg
# Captured frames/aoL-CuvX5C8/frame_16.jpg
# Captured frames/aoL-CuvX5C8/frame_17.jpg
# Captured frames/aoL-CuvX5C8/frame_18.jpg
# Video aoL-CuvX5C8 captured 19 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=14vVDLDeYlU
# [youtube] 14vVDLDeYlU: Downloading webpage
# [youtube] 14vVDLDeYlU: Downloading ios player API JSON
# [youtube] 14vVDLDeYlU: Downloading mweb player API JSON
# [youtube] 14vVDLDeYlU: Downloading m3u8 information
# Video 14vVDLDeYlU captured 0 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=F59zPRC5sHk
# [youtube] F59zPRC5sHk: Downloading webpage
# [youtube] F59zPRC5sHk: Downloading ios player API JSON
# [youtube] F59zPRC5sHk: Downloading mweb player API JSON
# [youtube] F59zPRC5sHk: Downloading m3u8 information
# Captured frames/F59zPRC5sHk/frame_0.jpg
# Captured frames/F59zPRC5sHk/frame_1.jpg
# Captured frames/F59zPRC5sHk/frame_2.jpg
# Video F59zPRC5sHk captured 3 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=cSLey_mJ-Hg
# [youtube] cSLey_mJ-Hg: Downloading webpage
# [youtube] cSLey_mJ-Hg: Downloading ios player API JSON
# [youtube] cSLey_mJ-Hg: Downloading mweb player API JSON
# [youtube] cSLey_mJ-Hg: Downloading m3u8 information
# Captured frames/cSLey_mJ-Hg/frame_0.jpg
# Captured frames/cSLey_mJ-Hg/frame_1.jpg
# Captured frames/cSLey_mJ-Hg/frame_2.jpg
# Captured frames/cSLey_mJ-Hg/frame_3.jpg
# Captured frames/cSLey_mJ-Hg/frame_4.jpg
# Captured frames/cSLey_mJ-Hg/frame_5.jpg
# Captured frames/cSLey_mJ-Hg/frame_6.jpg
# Captured frames/cSLey_mJ-Hg/frame_7.jpg
# Captured frames/cSLey_mJ-Hg/frame_8.jpg
# Captured frames/cSLey_mJ-Hg/frame_9.jpg
# Captured frames/cSLey_mJ-Hg/frame_10.jpg
# Captured frames/cSLey_mJ-Hg/frame_11.jpg
# Captured frames/cSLey_mJ-Hg/frame_12.jpg
# Captured frames/cSLey_mJ-Hg/frame_13.jpg
# Captured frames/cSLey_mJ-Hg/frame_14.jpg
# Captured frames/cSLey_mJ-Hg/frame_15.jpg
# Captured frames/cSLey_mJ-Hg/frame_16.jpg
# Captured frames/cSLey_mJ-Hg/frame_17.jpg
# Captured frames/cSLey_mJ-Hg/frame_18.jpg
# Captured frames/cSLey_mJ-Hg/frame_19.jpg
# Captured frames/cSLey_mJ-Hg/frame_20.jpg
# Captured frames/cSLey_mJ-Hg/frame_21.jpg
# Captured frames/cSLey_mJ-Hg/frame_22.jpg
# Captured frames/cSLey_mJ-Hg/frame_23.jpg
# Captured frames/cSLey_mJ-Hg/frame_24.jpg
# Captured frames/cSLey_mJ-Hg/frame_25.jpg
# Captured frames/cSLey_mJ-Hg/frame_26.jpg
# Captured frames/cSLey_mJ-Hg/frame_27.jpg
# Captured frames/cSLey_mJ-Hg/frame_28.jpg
# Captured frames/cSLey_mJ-Hg/frame_29.jpg
# Captured frames/cSLey_mJ-Hg/frame_30.jpg
# Captured frames/cSLey_mJ-Hg/frame_31.jpg
# Captured frames/cSLey_mJ-Hg/frame_32.jpg
# Captured frames/cSLey_mJ-Hg/frame_33.jpg
# Captured frames/cSLey_mJ-Hg/frame_34.jpg
# Captured frames/cSLey_mJ-Hg/frame_35.jpg
# Captured frames/cSLey_mJ-Hg/frame_36.jpg
# Captured frames/cSLey_mJ-Hg/frame_37.jpg
# Captured frames/cSLey_mJ-Hg/frame_38.jpg
# Captured frames/cSLey_mJ-Hg/frame_39.jpg
# Captured frames/cSLey_mJ-Hg/frame_40.jpg
# Captured frames/cSLey_mJ-Hg/frame_41.jpg
# Captured frames/cSLey_mJ-Hg/frame_42.jpg
# Captured frames/cSLey_mJ-Hg/frame_43.jpg
# Captured frames/cSLey_mJ-Hg/frame_44.jpg
# Captured frames/cSLey_mJ-Hg/frame_45.jpg
# Captured frames/cSLey_mJ-Hg/frame_46.jpg
# Captured frames/cSLey_mJ-Hg/frame_47.jpg
# Captured frames/cSLey_mJ-Hg/frame_48.jpg
# Captured frames/cSLey_mJ-Hg/frame_49.jpg
# Captured frames/cSLey_mJ-Hg/frame_50.jpg
# Captured frames/cSLey_mJ-Hg/frame_51.jpg
# Captured frames/cSLey_mJ-Hg/frame_52.jpg
# Captured frames/cSLey_mJ-Hg/frame_53.jpg
# Captured frames/cSLey_mJ-Hg/frame_54.jpg
# Captured frames/cSLey_mJ-Hg/frame_55.jpg
# Captured frames/cSLey_mJ-Hg/frame_56.jpg
# Captured frames/cSLey_mJ-Hg/frame_57.jpg
# Captured frames/cSLey_mJ-Hg/frame_58.jpg
# Captured frames/cSLey_mJ-Hg/frame_59.jpg
# Captured frames/cSLey_mJ-Hg/frame_60.jpg
# Captured frames/cSLey_mJ-Hg/frame_61.jpg
# Captured frames/cSLey_mJ-Hg/frame_62.jpg
# Captured frames/cSLey_mJ-Hg/frame_63.jpg
# Captured frames/cSLey_mJ-Hg/frame_64.jpg
# Captured frames/cSLey_mJ-Hg/frame_65.jpg
# Captured frames/cSLey_mJ-Hg/frame_66.jpg
# Captured frames/cSLey_mJ-Hg/frame_67.jpg
# Captured frames/cSLey_mJ-Hg/frame_68.jpg
# Captured frames/cSLey_mJ-Hg/frame_69.jpg
# Captured frames/cSLey_mJ-Hg/frame_70.jpg
# Captured frames/cSLey_mJ-Hg/frame_71.jpg
# Captured frames/cSLey_mJ-Hg/frame_72.jpg
# Captured frames/cSLey_mJ-Hg/frame_73.jpg
# Captured frames/cSLey_mJ-Hg/frame_74.jpg
# Video cSLey_mJ-Hg captured 75 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=qvicI8CjSXg
# [youtube] qvicI8CjSXg: Downloading webpage
# [youtube] qvicI8CjSXg: Downloading ios player API JSON
# [youtube] qvicI8CjSXg: Downloading mweb player API JSON
# [youtube] qvicI8CjSXg: Downloading m3u8 information
# Captured frames/qvicI8CjSXg/frame_0.jpg
# Captured frames/qvicI8CjSXg/frame_1.jpg
# Captured frames/qvicI8CjSXg/frame_2.jpg
# Video qvicI8CjSXg captured 3 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=m2E2JuVxjh0
# [youtube] m2E2JuVxjh0: Downloading webpage
# [youtube] m2E2JuVxjh0: Downloading ios player API JSON
# [youtube] m2E2JuVxjh0: Downloading mweb player API JSON
# [youtube] m2E2JuVxjh0: Downloading m3u8 information
# Captured frames/m2E2JuVxjh0/frame_0.jpg
# Video m2E2JuVxjh0 captured 1 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=mfT4ZdAxrcY
# [youtube] mfT4ZdAxrcY: Downloading webpage
# [youtube] mfT4ZdAxrcY: Downloading ios player API JSON
# [youtube] mfT4ZdAxrcY: Downloading mweb player API JSON
# [youtube] mfT4ZdAxrcY: Downloading m3u8 information
# Captured frames/mfT4ZdAxrcY/frame_0.jpg
# Captured frames/mfT4ZdAxrcY/frame_1.jpg
# Captured frames/mfT4ZdAxrcY/frame_2.jpg
# Captured frames/mfT4ZdAxrcY/frame_3.jpg
# Captured frames/mfT4ZdAxrcY/frame_4.jpg
# Captured frames/mfT4ZdAxrcY/frame_5.jpg
# Captured frames/mfT4ZdAxrcY/frame_6.jpg
# Captured frames/mfT4ZdAxrcY/frame_7.jpg
# Captured frames/mfT4ZdAxrcY/frame_8.jpg
# Captured frames/mfT4ZdAxrcY/frame_9.jpg
# Captured frames/mfT4ZdAxrcY/frame_10.jpg
# Captured frames/mfT4ZdAxrcY/frame_11.jpg
# Captured frames/mfT4ZdAxrcY/frame_12.jpg
# Captured frames/mfT4ZdAxrcY/frame_13.jpg
# Captured frames/mfT4ZdAxrcY/frame_14.jpg
# Captured frames/mfT4ZdAxrcY/frame_15.jpg
# Captured frames/mfT4ZdAxrcY/frame_16.jpg
# Captured frames/mfT4ZdAxrcY/frame_17.jpg
# Captured frames/mfT4ZdAxrcY/frame_18.jpg
# Captured frames/mfT4ZdAxrcY/frame_19.jpg
# Captured frames/mfT4ZdAxrcY/frame_20.jpg
# Captured frames/mfT4ZdAxrcY/frame_21.jpg
# Captured frames/mfT4ZdAxrcY/frame_22.jpg
# Captured frames/mfT4ZdAxrcY/frame_23.jpg
# Captured frames/mfT4ZdAxrcY/frame_24.jpg
# Captured frames/mfT4ZdAxrcY/frame_25.jpg
# Captured frames/mfT4ZdAxrcY/frame_26.jpg
# Captured frames/mfT4ZdAxrcY/frame_27.jpg
# Captured frames/mfT4ZdAxrcY/frame_28.jpg
# Captured frames/mfT4ZdAxrcY/frame_29.jpg
# Captured frames/mfT4ZdAxrcY/frame_30.jpg
# Captured frames/mfT4ZdAxrcY/frame_31.jpg
# Captured frames/mfT4ZdAxrcY/frame_32.jpg
# Captured frames/mfT4ZdAxrcY/frame_33.jpg
# Captured frames/mfT4ZdAxrcY/frame_34.jpg
# Captured frames/mfT4ZdAxrcY/frame_35.jpg
# Captured frames/mfT4ZdAxrcY/frame_36.jpg
# Captured frames/mfT4ZdAxrcY/frame_37.jpg
# Captured frames/mfT4ZdAxrcY/frame_38.jpg
# Captured frames/mfT4ZdAxrcY/frame_39.jpg
# Captured frames/mfT4ZdAxrcY/frame_40.jpg
# Captured frames/mfT4ZdAxrcY/frame_41.jpg
# Captured frames/mfT4ZdAxrcY/frame_42.jpg
# Captured frames/mfT4ZdAxrcY/frame_43.jpg
# Captured frames/mfT4ZdAxrcY/frame_44.jpg
# ...
# [youtube] zUHRHN-5ckw: Downloading m3u8 information
# Captured frames/zUHRHN-5ckw/frame_0.jpg
# Video zUHRHN-5ckw captured 1 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=saMGtbQMltU
# [youtube] saMGtbQMltU: Downloading webpage
# [youtube] saMGtbQMltU: Downloading ios player API JSON
# [youtube] saMGtbQMltU: Downloading mweb player API JSON
# [youtube] saMGtbQMltU: Downloading m3u8 information
# Video saMGtbQMltU captured 0 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=DAlK20IEhEw
# [youtube] DAlK20IEhEw: Downloading webpage
# [youtube] DAlK20IEhEw: Downloading ios player API JSON
# [youtube] DAlK20IEhEw: Downloading mweb player API JSON
# [youtube] DAlK20IEhEw: Downloading m3u8 information
# Captured frames/DAlK20IEhEw/frame_0.jpg
# Captured frames/DAlK20IEhEw/frame_1.jpg
# Video DAlK20IEhEw captured 2 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=cQ5c_mD5Yik
# [youtube] cQ5c_mD5Yik: Downloading webpage
# [youtube] cQ5c_mD5Yik: Downloading ios player API JSON
# [youtube] cQ5c_mD5Yik: Downloading mweb player API JSON
# [youtube] cQ5c_mD5Yik: Downloading m3u8 information
# Video cQ5c_mD5Yik captured 0 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=TxvbNKgC5yw
# [youtube] TxvbNKgC5yw: Downloading webpage
# [youtube] TxvbNKgC5yw: Downloading ios player API JSON
# [youtube] TxvbNKgC5yw: Downloading mweb player API JSON
# [youtube] TxvbNKgC5yw: Downloading m3u8 information
# Video TxvbNKgC5yw captured 0 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=-GVvCG7snSk
# [youtube] -GVvCG7snSk: Downloading webpage
# [youtube] -GVvCG7snSk: Downloading ios player API JSON
# [youtube] -GVvCG7snSk: Downloading mweb player API JSON
# [youtube] -GVvCG7snSk: Downloading m3u8 information
# Video -GVvCG7snSk captured 0 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=sNqcfydq5Fw
# [youtube] sNqcfydq5Fw: Downloading webpage
# [youtube] sNqcfydq5Fw: Downloading ios player API JSON
# [youtube] sNqcfydq5Fw: Downloading mweb player API JSON
# [youtube] sNqcfydq5Fw: Downloading m3u8 information
# Captured frames/sNqcfydq5Fw/frame_0.jpg
# Captured frames/sNqcfydq5Fw/frame_1.jpg
# Video sNqcfydq5Fw captured 2 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=kh5Q7wR7B1k
# [youtube] kh5Q7wR7B1k: Downloading webpage
# [youtube] kh5Q7wR7B1k: Downloading ios player API JSON
# [youtube] kh5Q7wR7B1k: Downloading mweb player API JSON
# [youtube] kh5Q7wR7B1k: Downloading m3u8 information
# Captured frames/kh5Q7wR7B1k/frame_0.jpg
# Captured frames/kh5Q7wR7B1k/frame_1.jpg
# Video kh5Q7wR7B1k captured 2 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=gXANjaRTXXU
# [youtube] gXANjaRTXXU: Downloading webpage
# [youtube] gXANjaRTXXU: Downloading ios player API JSON
# [youtube] gXANjaRTXXU: Downloading mweb player API JSON
# [youtube] gXANjaRTXXU: Downloading m3u8 information
# Captured frames/gXANjaRTXXU/frame_0.jpg
# Captured frames/gXANjaRTXXU/frame_1.jpg
# Video gXANjaRTXXU captured 2 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=RELbfuVBzXs
# [youtube] RELbfuVBzXs: Downloading webpage
# [youtube] RELbfuVBzXs: Downloading ios player API JSON
# [youtube] RELbfuVBzXs: Downloading mweb player API JSON
# [youtube] RELbfuVBzXs: Downloading m3u8 information
# Captured frames/RELbfuVBzXs/frame_0.jpg
# Video RELbfuVBzXs captured 1 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=BjBmX37e1h0
# [youtube] BjBmX37e1h0: Downloading webpage
# [youtube] BjBmX37e1h0: Downloading ios player API JSON
# [youtube] BjBmX37e1h0: Downloading mweb player API JSON
# [youtube] BjBmX37e1h0: Downloading m3u8 information
# Captured frames/BjBmX37e1h0/frame_0.jpg
# Captured frames/BjBmX37e1h0/frame_1.jpg
# Captured frames/BjBmX37e1h0/frame_2.jpg
# Video BjBmX37e1h0 captured 3 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=NxQChgFFJbM
# [youtube] NxQChgFFJbM: Downloading webpage
# [youtube] NxQChgFFJbM: Downloading ios player API JSON
# [youtube] NxQChgFFJbM: Downloading mweb player API JSON
# [youtube] NxQChgFFJbM: Downloading m3u8 information
# Captured frames/NxQChgFFJbM/frame_0.jpg
# Captured frames/NxQChgFFJbM/frame_1.jpg
# Captured frames/NxQChgFFJbM/frame_2.jpg
# Captured frames/NxQChgFFJbM/frame_3.jpg
# Video NxQChgFFJbM captured 4 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=uzP3VU_cwj0
# [youtube] uzP3VU_cwj0: Downloading webpage
# [youtube] uzP3VU_cwj0: Downloading ios player API JSON
# [youtube] uzP3VU_cwj0: Downloading mweb player API JSON
# [youtube] uzP3VU_cwj0: Downloading m3u8 information
# Captured frames/uzP3VU_cwj0/frame_0.jpg
# Captured frames/uzP3VU_cwj0/frame_1.jpg
# Captured frames/uzP3VU_cwj0/frame_2.jpg
# Captured frames/uzP3VU_cwj0/frame_3.jpg
# Captured frames/uzP3VU_cwj0/frame_4.jpg
# Captured frames/uzP3VU_cwj0/frame_5.jpg
# Captured frames/uzP3VU_cwj0/frame_6.jpg
# Captured frames/uzP3VU_cwj0/frame_7.jpg
# Captured frames/uzP3VU_cwj0/frame_8.jpg
# Captured frames/uzP3VU_cwj0/frame_9.jpg
# Captured frames/uzP3VU_cwj0/frame_10.jpg
# Captured frames/uzP3VU_cwj0/frame_11.jpg
# Captured frames/uzP3VU_cwj0/frame_12.jpg
# Captured frames/uzP3VU_cwj0/frame_13.jpg
# Captured frames/uzP3VU_cwj0/frame_14.jpg
# Captured frames/uzP3VU_cwj0/frame_15.jpg
# Captured frames/uzP3VU_cwj0/frame_16.jpg
# Captured frames/uzP3VU_cwj0/frame_17.jpg
# Captured frames/uzP3VU_cwj0/frame_18.jpg
# Captured frames/uzP3VU_cwj0/frame_19.jpg
# Captured frames/uzP3VU_cwj0/frame_20.jpg
# Captured frames/uzP3VU_cwj0/frame_21.jpg
# Captured frames/uzP3VU_cwj0/frame_22.jpg
# Captured frames/uzP3VU_cwj0/frame_23.jpg
# Captured frames/uzP3VU_cwj0/frame_24.jpg
# Captured frames/uzP3VU_cwj0/frame_25.jpg
# Captured frames/uzP3VU_cwj0/frame_26.jpg
# Captured frames/uzP3VU_cwj0/frame_27.jpg
# Captured frames/uzP3VU_cwj0/frame_28.jpg
# Captured frames/uzP3VU_cwj0/frame_29.jpg
# Captured frames/uzP3VU_cwj0/frame_30.jpg
# Captured frames/uzP3VU_cwj0/frame_31.jpg
# Captured frames/uzP3VU_cwj0/frame_32.jpg
# Captured frames/uzP3VU_cwj0/frame_33.jpg
# Captured frames/uzP3VU_cwj0/frame_34.jpg
# Captured frames/uzP3VU_cwj0/frame_35.jpg
# Captured frames/uzP3VU_cwj0/frame_36.jpg
# Captured frames/uzP3VU_cwj0/frame_37.jpg
# Captured frames/uzP3VU_cwj0/frame_38.jpg
# Video uzP3VU_cwj0 captured 39 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=FZlscbGJpcs
# [youtube] FZlscbGJpcs: Downloading webpage
# [youtube] FZlscbGJpcs: Downloading ios player API JSON
# [youtube] FZlscbGJpcs: Downloading mweb player API JSON
# [youtube] FZlscbGJpcs: Downloading m3u8 information
# Captured frames/FZlscbGJpcs/frame_0.jpg
# Video FZlscbGJpcs captured 1 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=9pN8kD05gbI
# [youtube] 9pN8kD05gbI: Downloading webpage
# [youtube] 9pN8kD05gbI: Downloading ios player API JSON
# [youtube] 9pN8kD05gbI: Downloading mweb player API JSON
# [youtube] 9pN8kD05gbI: Downloading m3u8 information
# Captured frames/9pN8kD05gbI/frame_0.jpg
# Captured frames/9pN8kD05gbI/frame_1.jpg
# Video 9pN8kD05gbI captured 2 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=kF9KSoOQ4qY
# [youtube] kF9KSoOQ4qY: Downloading webpage
# [youtube] kF9KSoOQ4qY: Downloading ios player API JSON
# [youtube] kF9KSoOQ4qY: Downloading mweb player API JSON
# [youtube] kF9KSoOQ4qY: Downloading m3u8 information
# Captured frames/kF9KSoOQ4qY/frame_0.jpg
# Captured frames/kF9KSoOQ4qY/frame_1.jpg
# Video kF9KSoOQ4qY captured 2 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=mzuvuSom5SM
# [youtube] mzuvuSom5SM: Downloading webpage
# [youtube] mzuvuSom5SM: Downloading ios player API JSON
# [youtube] mzuvuSom5SM: Downloading mweb player API JSON
# [youtube] mzuvuSom5SM: Downloading m3u8 information
# Video mzuvuSom5SM captured 0 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Zh8BStDpxis
# [youtube] Zh8BStDpxis: Downloading webpage
# [youtube] Zh8BStDpxis: Downloading ios player API JSON
# [youtube] Zh8BStDpxis: Downloading mweb player API JSON
# [youtube] Zh8BStDpxis: Downloading m3u8 information
# Captured frames/Zh8BStDpxis/frame_0.jpg
# Video Zh8BStDpxis captured 1 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=UmTrV5g8v8E
# [youtube] UmTrV5g8v8E: Downloading webpage
# [youtube] UmTrV5g8v8E: Downloading ios player API JSON
# [youtube] UmTrV5g8v8E: Downloading mweb player API JSON
# [youtube] UmTrV5g8v8E: Downloading m3u8 information
# Captured frames/UmTrV5g8v8E/frame_0.jpg
# Video UmTrV5g8v8E captured 1 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=zuk6-MJrLvc
# [youtube] zuk6-MJrLvc: Downloading webpage
# [youtube] zuk6-MJrLvc: Downloading ios player API JSON
# [youtube] zuk6-MJrLvc: Downloading mweb player API JSON
# [youtube] zuk6-MJrLvc: Downloading m3u8 information
# Captured frames/zuk6-MJrLvc/frame_0.jpg
# Video zuk6-MJrLvc captured 1 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=_hmC3hsDUzo
# [youtube] _hmC3hsDUzo: Downloading webpage
# [youtube] _hmC3hsDUzo: Downloading ios player API JSON
# [youtube] _hmC3hsDUzo: Downloading mweb player API JSON
# [youtube] _hmC3hsDUzo: Downloading m3u8 information
# Captured frames/_hmC3hsDUzo/frame_0.jpg
# Video _hmC3hsDUzo captured 1 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=BkB4hz2fX_g
# [youtube] BkB4hz2fX_g: Downloading webpage
# [youtube] BkB4hz2fX_g: Downloading ios player API JSON
# [youtube] BkB4hz2fX_g: Downloading mweb player API JSON
# [youtube] BkB4hz2fX_g: Downloading m3u8 information
# Video BkB4hz2fX_g captured 0 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=1p9ilDVsuck
# [youtube] 1p9ilDVsuck: Downloading webpage
# [youtube] 1p9ilDVsuck: Downloading ios player API JSON
# [youtube] 1p9ilDVsuck: Downloading mweb player API JSON
# [youtube] 1p9ilDVsuck: Downloading m3u8 information
# Captured frames/1p9ilDVsuck/frame_0.jpg
# Video 1p9ilDVsuck captured 1 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=19feUbnQuWk
# [youtube] 19feUbnQuWk: Downloading webpage
# [youtube] 19feUbnQuWk: Downloading ios player API JSON
# [youtube] 19feUbnQuWk: Downloading mweb player API JSON
# [youtube] 19feUbnQuWk: Downloading m3u8 information
# Captured frames/19feUbnQuWk/frame_0.jpg
# Video 19feUbnQuWk captured 1 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=5eUlh3-q8-w
# [youtube] 5eUlh3-q8-w: Downloading webpage
# [youtube] 5eUlh3-q8-w: Downloading ios player API JSON
# [youtube] 5eUlh3-q8-w: Downloading mweb player API JSON
# [youtube] 5eUlh3-q8-w: Downloading m3u8 information
# Captured frames/5eUlh3-q8-w/frame_0.jpg
# Captured frames/5eUlh3-q8-w/frame_1.jpg
# Captured frames/5eUlh3-q8-w/frame_2.jpg
# Video 5eUlh3-q8-w captured 3 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=nkAl5BQOThI
# [youtube] nkAl5BQOThI: Downloading webpage
# [youtube] nkAl5BQOThI: Downloading ios player API JSON
# [youtube] nkAl5BQOThI: Downloading mweb player API JSON
# [youtube] nkAl5BQOThI: Downloading m3u8 information
# [youtube] nkAl5BQOThI: Downloading MPD manifest
# Captured frames/nkAl5BQOThI/frame_0.jpg
# Video nkAl5BQOThI captured 1 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=nxoPqTeRcaM
# [youtube] nxoPqTeRcaM: Downloading webpage
# [youtube] nxoPqTeRcaM: Downloading ios player API JSON
# [youtube] nxoPqTeRcaM: Downloading mweb player API JSON
# [youtube] nxoPqTeRcaM: Downloading m3u8 information
# Captured frames/nxoPqTeRcaM/frame_0.jpg
# Video nxoPqTeRcaM captured 1 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=vXmFzLBWwu0
# [youtube] vXmFzLBWwu0: Downloading webpage
# [youtube] vXmFzLBWwu0: Downloading ios player API JSON
# [youtube] vXmFzLBWwu0: Downloading mweb player API JSON
# [youtube] vXmFzLBWwu0: Downloading m3u8 information
# Captured frames/vXmFzLBWwu0/frame_0.jpg
# Video vXmFzLBWwu0 captured 1 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=2xHsqyUvJUU
# [youtube] 2xHsqyUvJUU: Downloading webpage
# [youtube] 2xHsqyUvJUU: Downloading ios player API JSON
# [youtube] 2xHsqyUvJUU: Downloading mweb player API JSON
# [youtube] 2xHsqyUvJUU: Downloading m3u8 information
# Captured frames/2xHsqyUvJUU/frame_0.jpg
# Video 2xHsqyUvJUU captured 1 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=330LgAm5hAg
# [youtube] 330LgAm5hAg: Downloading webpage
# [youtube] 330LgAm5hAg: Downloading ios player API JSON
# [youtube] 330LgAm5hAg: Downloading mweb player API JSON
# [youtube] 330LgAm5hAg: Downloading m3u8 information
# Captured frames/330LgAm5hAg/frame_0.jpg
# Video 330LgAm5hAg captured 1 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=kfoDowM_Xkg
# [youtube] kfoDowM_Xkg: Downloading webpage
# [youtube] kfoDowM_Xkg: Downloading ios player API JSON
# [youtube] kfoDowM_Xkg: Downloading mweb player API JSON
# [youtube] kfoDowM_Xkg: Downloading m3u8 information
# Captured frames/kfoDowM_Xkg/frame_0.jpg
# Captured frames/kfoDowM_Xkg/frame_1.jpg
# Video kfoDowM_Xkg captured 2 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=YaAIfFHnZbc
# [youtube] YaAIfFHnZbc: Downloading webpage
# [youtube] YaAIfFHnZbc: Downloading ios player API JSON
# [youtube] YaAIfFHnZbc: Downloading mweb player API JSON
# [youtube] YaAIfFHnZbc: Downloading m3u8 information
# Captured frames/YaAIfFHnZbc/frame_0.jpg
# Captured frames/YaAIfFHnZbc/frame_1.jpg
# Video YaAIfFHnZbc captured 2 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=X2yQSBMANJ0
# [youtube] X2yQSBMANJ0: Downloading webpage
# [youtube] X2yQSBMANJ0: Downloading ios player API JSON
# [youtube] X2yQSBMANJ0: Downloading mweb player API JSON
# [youtube] X2yQSBMANJ0: Downloading m3u8 information
# Captured frames/X2yQSBMANJ0/frame_0.jpg
# Captured frames/X2yQSBMANJ0/frame_1.jpg
# Captured frames/X2yQSBMANJ0/frame_2.jpg
# Video X2yQSBMANJ0 captured 3 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Mdit36sFnv8
# [youtube] Mdit36sFnv8: Downloading webpage
# [youtube] Mdit36sFnv8: Downloading ios player API JSON
# [youtube] Mdit36sFnv8: Downloading mweb player API JSON
# [youtube] Mdit36sFnv8: Downloading m3u8 information
# Captured frames/Mdit36sFnv8/frame_0.jpg
# Captured frames/Mdit36sFnv8/frame_1.jpg
# Video Mdit36sFnv8 captured 2 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=b4hg7LyaTBA
# [youtube] b4hg7LyaTBA: Downloading webpage
# [youtube] b4hg7LyaTBA: Downloading ios player API JSON
# [youtube] b4hg7LyaTBA: Downloading mweb player API JSON
# [youtube] b4hg7LyaTBA: Downloading m3u8 information
# Captured frames/b4hg7LyaTBA/frame_0.jpg
# Captured frames/b4hg7LyaTBA/frame_1.jpg
# Video b4hg7LyaTBA captured 2 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=oBz5e36iRYg
# [youtube] oBz5e36iRYg: Downloading webpage
# [youtube] oBz5e36iRYg: Downloading ios player API JSON
# [youtube] oBz5e36iRYg: Downloading mweb player API JSON
# [youtube] oBz5e36iRYg: Downloading m3u8 information
# Captured frames/oBz5e36iRYg/frame_0.jpg
# Video oBz5e36iRYg captured 1 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=_JEmnoNSlQQ
# [youtube] _JEmnoNSlQQ: Downloading webpage
# [youtube] _JEmnoNSlQQ: Downloading ios player API JSON
# [youtube] _JEmnoNSlQQ: Downloading mweb player API JSON
# [youtube] _JEmnoNSlQQ: Downloading m3u8 information
# Captured frames/_JEmnoNSlQQ/frame_0.jpg
# Captured frames/_JEmnoNSlQQ/frame_1.jpg
# Captured frames/_JEmnoNSlQQ/frame_2.jpg
# Captured frames/_JEmnoNSlQQ/frame_3.jpg
# Captured frames/_JEmnoNSlQQ/frame_4.jpg
# Captured frames/_JEmnoNSlQQ/frame_5.jpg
# Captured frames/_JEmnoNSlQQ/frame_6.jpg
# Video _JEmnoNSlQQ captured 7 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=-wsKB9QFxoU
# [youtube] -wsKB9QFxoU: Downloading webpage
# [youtube] -wsKB9QFxoU: Downloading ios player API JSON
# [youtube] -wsKB9QFxoU: Downloading mweb player API JSON
# [youtube] -wsKB9QFxoU: Downloading m3u8 information
# Captured frames/-wsKB9QFxoU/frame_0.jpg
# Video -wsKB9QFxoU captured 1 frames.
# [youtube] Extracting URL: https://www.youtube.com/watch?v=3Lui65H8Qo0
# [youtube] 3Lui65H8Qo0: Downloading webpage
# [youtube] 3Lui65H8Qo0: Downloading ios player API JSON
# [youtube] 3Lui65H8Qo0: Downloading mweb player API JSON
# [youtube] 3Lui65H8Qo0: Downloading m3u8 information
# Captured frames/3Lui65H8Qo0/frame_0.jpg
# Video 3Lui65H8Qo0 captured 1 frames.
# Average frame counts saved to 'average_frame_counts.csv'.
